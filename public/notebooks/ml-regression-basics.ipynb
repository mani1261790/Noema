# %% [markdown]
# # 線形回帰の基礎
#
# 特徴量 x と目的変数 y の関係を一次式で近似します。

# %% [markdown]
# ## 損失関数
# 平均二乗誤差 (MSE) を最小化するパラメータを探します。

# %%
import numpy as np
x = np.array([1, 2, 3, 4])
y = np.array([2, 4, 6, 8])
