# %% [markdown]
# <a href="https://colab.research.google.com/github/NeuromatchAcademy/course-content-dl/blob/main/tutorials/Module_WrapUps/ReinforcementLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a> &nbsp; <a href="https://kaggle.com/kernels/welcome?src=https://raw.githubusercontent.com/NeuromatchAcademy/course-content-dl/main/tutorials/Module_WrapUps/ReinforcementLearning.ipynb" target="_parent"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open in Kaggle"/></a>

# %% [markdown]
# # ディープラーニング: 強化学習まとめ

# %% [markdown]
# ## ポッドキャスト パネルディスカッション
#
# Neuromatch Academyは、ポッドキャストBrain InspiredのPaul Middlebrooksと協力して、コンテンツモジュールに関する一連のパネルディスカッションを開催しています。
#
# 第6回セッションでは、ディープラーニングの*強化学習*モジュールを取り上げ、パネリストには[Alona Fyshe](http://webdocs.cs.ualberta.ca/~alona/)、[Jane Wang](http://www.janexwang.com/)、および[Ida Momennejad](https://www.momen-nejad.org/)が参加しています。
#
# こちらから[視聴](https://braininspired.co/podcast/nma-6/)するか、下の埋め込みオーディオでお聴きください！

# %%
# @markdown
from IPython.display import IFrame
IFrame(src='https://braininspired.castos.com/player/625374', width='100%', height='150')
