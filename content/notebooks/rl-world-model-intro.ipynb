# %% [markdown]
# # 強化学習と世界モデル\n\n世界モデルは環境の遷移を内部で近似し、計画的な行動選択を支援します。

# %% [markdown]
# ## モデルベース強化学習\nモデルフリー手法と比べてサンプル効率が高くなる可能性があります。

# %%
states = ['s0', 's1']\nactions = ['left', 'right']\nprint(states, actions)
